# %%
def read_file(file_name):
	with open(file_name, "r") as f:
		data = f.read().splitlines()
	return data

# %%
EXAMPLE_FILE = "example"
INPUT_FILE = "input"
ROUNDS = 20

# %%
class Monkey:
	def __init__(self, monkey_id, items=[], operand=None, constant=0, rhs_is_value=False, modulo=1, positive_action=0, negative_action=0):
		self.id = monkey_id
		self.items = items
		self.operand = operand
		self.constant = constant
		self.rhs_is_value = rhs_is_value
		self.modulo = modulo
		self.positive_action = positive_action
		self.negative_action = negative_action
		self.inspected = 0

	def __repr__(self):
		return f"Monkey(id={self.id}, items={self.items}, op={self.operand}, constant={self.constant}, rhs_is_value={self.rhs_is_value}, modulo={self.modulo}, positive_action={self.positive_action}, negative_action={self.negative_action}, inspected={self.inspected}"
	
	def operate(self, value):
		result = 0
		action = ""
		rhs = value if self.rhs_is_value else self.constant
		if self.operand == '*':
			action = "is multiplied"
			result = value * rhs
		elif self.operand == '+':
			action = "increases"
			result = value + rhs
		else:
			raise ValueError("unkown operand")
		print(f"Worry level {action} by {rhs} to {result}.")
		return result
	
	def inspect(self):
		item = self.items[0]
		del self.items[0]
		print(f"Monkey inspects an item with a worry level of {item}.")
		self.inspected += 1
		return item
	
	def get_bored(self, item):
		result = item // 3
		print(f"Monkey gets bored with item, Worry level is divided by 3 to {result}.")
		if result % self.modulo == 0:
			print(f"Current worry level is divisible by {self.modulo}.")
			return True
		else:
			print(f"Current worry level is not divisible by {self.modulo}.")
			return False

	def throw(self, item, test_result):
		monkey_id = self.positive_action if test_result else self.negative_action
		print(f"Item with worry level {item} is thrown to monkey {monkey_id}.")
		return (item, monkey_id)

	def act(self):
		item = self.inspect()
		item = self.operate(item)
		return self.throw(item // 3, self.get_bored(item))

# %%
def prepare_data(file_name):
	monkeys = []
	monkey = None
	data = read_file(file_name)
	for line in data:
		if line == '':
			monkeys.append(monkey)
			continue
		line = line.split(':')
		if line[0][0:6] == "Monkey":
			monkey = Monkey(int(line[0][-1]))
		elif line[0] == "  Starting items":
			monkey.items = [int(item) for item in line[1].split(", ")]
		elif line[0] == "  Operation":
			_,_,_,_,monkey.operand,rhs = line[1].split(' ')
			if rhs.isalpha():
				monkey.rhs_is_value = True
			else:
				monkey.constant = int(rhs)
		elif line[0] == "  Test":
			_,_,_,m = line[1].split(' ')
			monkey.modulo = int(m)
		elif line[0] == "    If true":
			_,_,_,_, action = line[1].split(' ')
			monkey.positive_action = int(action)
		elif line[0] == "    If false":
			_,_,_,_, action = line[1].split(' ')
			monkey.negative_action = int(action)
			
	monkeys.append(monkey)
	return monkeys

example_monkeys = prepare_data(EXAMPLE_FILE)
print(example_monkeys)
# Out:
# [Monkey(id=0, items=[79, 98], op=*, constant=19, rhs_is_value=False, modulo=23, positive_action=2, negative_action=3, inspected=0, Monkey(id=1, items=[54, 65, 75, 74], op=+, constant=6, rhs_is_value=False, modulo=19, positive_action=2, negative_action=0, inspected=0, Monkey(id=2, items=[79, 60, 97], op=*, constant=0, rhs_is_value=True, modulo=13, positive_action=1, negative_action=3, inspected=0, Monkey(id=3, items=[74], op=+, constant=3, rhs_is_value=False, modulo=17, positive_action=0, negative_action=1, inspected=0]

# %%
def solve_part1(monkeys):
	for i in range(ROUNDS):
		# print(f"found{i}", monkeys)
		for monkey in monkeys:
			# print(f"### Monkey {monkey.id}:")
			# print(monkey)
			while monkey.items:
				item, monkey_id = monkey.act()
				monkeys[monkey_id].items.append(item)
	# print(monkeys)
	activity = [monkey.inspected for monkey in monkeys]
	activity.sort(reverse=True)
	print(activity)
	return activity[0] * activity[1]
solve_part1(prepare_data(EXAMPLE_FILE))
solve_part1(prepare_data(INPUT_FILE))
# Out:
# Monkey inspects an item with a worry level of 79.
# Worry level is multiplied by 19 to 1501.
# Monkey gets bored with item, Worry level is divided by 3 to 500.
# Current worry level is not divisible by 23.
# Item with worry level 500 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 98.
# Worry level is multiplied by 19 to 1862.
# Monkey gets bored with item, Worry level is divided by 3 to 620.
# Current worry level is not divisible by 23.
# Item with worry level 620 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 54.
# Worry level increases by 6 to 60.
# Monkey gets bored with item, Worry level is divided by 3 to 20.
# Current worry level is not divisible by 19.
# Item with worry level 20 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 65.
# Worry level increases by 6 to 71.
# Monkey gets bored with item, Worry level is divided by 3 to 23.
# Current worry level is not divisible by 19.
# Item with worry level 23 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 75.
# Worry level increases by 6 to 81.
# Monkey gets bored with item, Worry level is divided by 3 to 27.
# Current worry level is not divisible by 19.
# Item with worry level 27 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 74.
# Worry level increases by 6 to 80.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 19.
# Item with worry level 26 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 79.
# Worry level is multiplied by 79 to 6241.
# Monkey gets bored with item, Worry level is divided by 3 to 2080.
# Current worry level is divisible by 13.
# Item with worry level 2080 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 60.
# Worry level is multiplied by 60 to 3600.
# Monkey gets bored with item, Worry level is divided by 3 to 1200.
# Current worry level is not divisible by 13.
# Item with worry level 1200 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 97.
# Worry level is multiplied by 97 to 9409.
# Monkey gets bored with item, Worry level is divided by 3 to 3136.
# Current worry level is not divisible by 13.
# Item with worry level 3136 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 74.
# Worry level increases by 3 to 77.
# Monkey gets bored with item, Worry level is divided by 3 to 25.
# Current worry level is not divisible by 17.
# Item with worry level 25 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 500.
# Worry level increases by 3 to 503.
# Monkey gets bored with item, Worry level is divided by 3 to 167.
# Current worry level is not divisible by 17.
# Item with worry level 167 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 620.
# Worry level increases by 3 to 623.
# Monkey gets bored with item, Worry level is divided by 3 to 207.
# Current worry level is not divisible by 17.
# Item with worry level 207 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 1200.
# Worry level increases by 3 to 1203.
# Monkey gets bored with item, Worry level is divided by 3 to 401.
# Current worry level is not divisible by 17.
# Item with worry level 401 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 3136.
# Worry level increases by 3 to 3139.
# Monkey gets bored with item, Worry level is divided by 3 to 1046.
# Current worry level is not divisible by 17.
# Item with worry level 1046 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 20.
# Worry level is multiplied by 19 to 380.
# Monkey gets bored with item, Worry level is divided by 3 to 126.
# Current worry level is not divisible by 23.
# Item with worry level 126 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 23.
# Worry level is multiplied by 19 to 437.
# Monkey gets bored with item, Worry level is divided by 3 to 145.
# Current worry level is not divisible by 23.
# Item with worry level 145 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 27.
# Worry level is multiplied by 19 to 513.
# Monkey gets bored with item, Worry level is divided by 3 to 171.
# Current worry level is not divisible by 23.
# Item with worry level 171 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 26.
# Worry level is multiplied by 19 to 494.
# Monkey gets bored with item, Worry level is divided by 3 to 164.
# Current worry level is not divisible by 23.
# Item with worry level 164 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 2080.
# Worry level increases by 6 to 2086.
# Monkey gets bored with item, Worry level is divided by 3 to 695.
# Current worry level is not divisible by 19.
# Item with worry level 695 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 25.
# Worry level increases by 6 to 31.
# Monkey gets bored with item, Worry level is divided by 3 to 10.
# Current worry level is not divisible by 19.
# Item with worry level 10 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 167.
# Worry level increases by 6 to 173.
# Monkey gets bored with item, Worry level is divided by 3 to 57.
# Current worry level is divisible by 19.
# Item with worry level 57 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 207.
# Worry level increases by 6 to 213.
# Monkey gets bored with item, Worry level is divided by 3 to 71.
# Current worry level is not divisible by 19.
# Item with worry level 71 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 401.
# Worry level increases by 6 to 407.
# Monkey gets bored with item, Worry level is divided by 3 to 135.
# Current worry level is not divisible by 19.
# Item with worry level 135 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 1046.
# Worry level increases by 6 to 1052.
# Monkey gets bored with item, Worry level is divided by 3 to 350.
# Current worry level is not divisible by 19.
# Item with worry level 350 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 57.
# Worry level is multiplied by 57 to 3249.
# Monkey gets bored with item, Worry level is divided by 3 to 1083.
# Current worry level is not divisible by 13.
# Item with worry level 1083 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 126.
# Worry level increases by 3 to 129.
# Monkey gets bored with item, Worry level is divided by 3 to 43.
# Current worry level is not divisible by 17.
# Item with worry level 43 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 145.
# Worry level increases by 3 to 148.
# Monkey gets bored with item, Worry level is divided by 3 to 49.
# Current worry level is not divisible by 17.
# Item with worry level 49 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 171.
# Worry level increases by 3 to 174.
# Monkey gets bored with item, Worry level is divided by 3 to 58.
# Current worry level is not divisible by 17.
# Item with worry level 58 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 164.
# Worry level increases by 3 to 167.
# Monkey gets bored with item, Worry level is divided by 3 to 55.
# Current worry level is not divisible by 17.
# Item with worry level 55 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 1083.
# Worry level increases by 3 to 1086.
# Monkey gets bored with item, Worry level is divided by 3 to 362.
# Current worry level is not divisible by 17.
# Item with worry level 362 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 695.
# Worry level is multiplied by 19 to 13205.
# Monkey gets bored with item, Worry level is divided by 3 to 4401.
# Current worry level is not divisible by 23.
# Item with worry level 4401 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 10.
# Worry level is multiplied by 19 to 190.
# Monkey gets bored with item, Worry level is divided by 3 to 63.
# Current worry level is not divisible by 23.
# Item with worry level 63 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 71.
# Worry level is multiplied by 19 to 1349.
# Monkey gets bored with item, Worry level is divided by 3 to 449.
# Current worry level is not divisible by 23.
# Item with worry level 449 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 135.
# Worry level is multiplied by 19 to 2565.
# Monkey gets bored with item, Worry level is divided by 3 to 855.
# Current worry level is not divisible by 23.
# Item with worry level 855 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 350.
# Worry level is multiplied by 19 to 6650.
# Monkey gets bored with item, Worry level is divided by 3 to 2216.
# Current worry level is not divisible by 23.
# Item with worry level 2216 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 43.
# Worry level increases by 6 to 49.
# Monkey gets bored with item, Worry level is divided by 3 to 16.
# Current worry level is not divisible by 19.
# Item with worry level 16 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 49.
# Worry level increases by 6 to 55.
# Monkey gets bored with item, Worry level is divided by 3 to 18.
# Current worry level is not divisible by 19.
# Item with worry level 18 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 58.
# Worry level increases by 6 to 64.
# Monkey gets bored with item, Worry level is divided by 3 to 21.
# Current worry level is not divisible by 19.
# Item with worry level 21 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 55.
# Worry level increases by 6 to 61.
# Monkey gets bored with item, Worry level is divided by 3 to 20.
# Current worry level is not divisible by 19.
# Item with worry level 20 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 362.
# Worry level increases by 6 to 368.
# Monkey gets bored with item, Worry level is divided by 3 to 122.
# Current worry level is not divisible by 19.
# Item with worry level 122 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 4401.
# Worry level increases by 3 to 4404.
# Monkey gets bored with item, Worry level is divided by 3 to 1468.
# Current worry level is not divisible by 17.
# Item with worry level 1468 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 63.
# Worry level increases by 3 to 66.
# Monkey gets bored with item, Worry level is divided by 3 to 22.
# Current worry level is not divisible by 17.
# Item with worry level 22 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 449.
# Worry level increases by 3 to 452.
# Monkey gets bored with item, Worry level is divided by 3 to 150.
# Current worry level is not divisible by 17.
# Item with worry level 150 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 855.
# Worry level increases by 3 to 858.
# Monkey gets bored with item, Worry level is divided by 3 to 286.
# Current worry level is not divisible by 17.
# Item with worry level 286 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 2216.
# Worry level increases by 3 to 2219.
# Monkey gets bored with item, Worry level is divided by 3 to 739.
# Current worry level is not divisible by 17.
# Item with worry level 739 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 16.
# Worry level is multiplied by 19 to 304.
# Monkey gets bored with item, Worry level is divided by 3 to 101.
# Current worry level is not divisible by 23.
# Item with worry level 101 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 18.
# Worry level is multiplied by 19 to 342.
# Monkey gets bored with item, Worry level is divided by 3 to 114.
# Current worry level is not divisible by 23.
# Item with worry level 114 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 21.
# Worry level is multiplied by 19 to 399.
# Monkey gets bored with item, Worry level is divided by 3 to 133.
# Current worry level is not divisible by 23.
# Item with worry level 133 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 20.
# Worry level is multiplied by 19 to 380.
# Monkey gets bored with item, Worry level is divided by 3 to 126.
# Current worry level is not divisible by 23.
# Item with worry level 126 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 122.
# Worry level is multiplied by 19 to 2318.
# Monkey gets bored with item, Worry level is divided by 3 to 772.
# Current worry level is not divisible by 23.
# Item with worry level 772 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 1468.
# Worry level increases by 6 to 1474.
# Monkey gets bored with item, Worry level is divided by 3 to 491.
# Current worry level is not divisible by 19.
# Item with worry level 491 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 22.
# Worry level increases by 6 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 19.
# Item with worry level 9 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 150.
# Worry level increases by 6 to 156.
# Monkey gets bored with item, Worry level is divided by 3 to 52.
# Current worry level is not divisible by 19.
# Item with worry level 52 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 286.
# Worry level increases by 6 to 292.
# Monkey gets bored with item, Worry level is divided by 3 to 97.
# Current worry level is not divisible by 19.
# Item with worry level 97 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 739.
# Worry level increases by 6 to 745.
# Monkey gets bored with item, Worry level is divided by 3 to 248.
# Current worry level is not divisible by 19.
# Item with worry level 248 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 101.
# Worry level increases by 3 to 104.
# Monkey gets bored with item, Worry level is divided by 3 to 34.
# Current worry level is divisible by 17.
# Item with worry level 34 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 114.
# Worry level increases by 3 to 117.
# Monkey gets bored with item, Worry level is divided by 3 to 39.
# Current worry level is not divisible by 17.
# Item with worry level 39 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 133.
# Worry level increases by 3 to 136.
# Monkey gets bored with item, Worry level is divided by 3 to 45.
# Current worry level is not divisible by 17.
# Item with worry level 45 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 126.
# Worry level increases by 3 to 129.
# Monkey gets bored with item, Worry level is divided by 3 to 43.
# Current worry level is not divisible by 17.
# Item with worry level 43 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 772.
# Worry level increases by 3 to 775.
# Monkey gets bored with item, Worry level is divided by 3 to 258.
# Current worry level is not divisible by 17.
# Item with worry level 258 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 491.
# Worry level is multiplied by 19 to 9329.
# Monkey gets bored with item, Worry level is divided by 3 to 3109.
# Current worry level is not divisible by 23.
# Item with worry level 3109 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 9.
# Worry level is multiplied by 19 to 171.
# Monkey gets bored with item, Worry level is divided by 3 to 57.
# Current worry level is not divisible by 23.
# Item with worry level 57 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 52.
# Worry level is multiplied by 19 to 988.
# Monkey gets bored with item, Worry level is divided by 3 to 329.
# Current worry level is not divisible by 23.
# Item with worry level 329 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 97.
# Worry level is multiplied by 19 to 1843.
# Monkey gets bored with item, Worry level is divided by 3 to 614.
# Current worry level is not divisible by 23.
# Item with worry level 614 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 248.
# Worry level is multiplied by 19 to 4712.
# Monkey gets bored with item, Worry level is divided by 3 to 1570.
# Current worry level is not divisible by 23.
# Item with worry level 1570 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 34.
# Worry level is multiplied by 19 to 646.
# Monkey gets bored with item, Worry level is divided by 3 to 215.
# Current worry level is not divisible by 23.
# Item with worry level 215 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 39.
# Worry level increases by 6 to 45.
# Monkey gets bored with item, Worry level is divided by 3 to 15.
# Current worry level is not divisible by 19.
# Item with worry level 15 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 45.
# Worry level increases by 6 to 51.
# Monkey gets bored with item, Worry level is divided by 3 to 17.
# Current worry level is not divisible by 19.
# Item with worry level 17 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 43.
# Worry level increases by 6 to 49.
# Monkey gets bored with item, Worry level is divided by 3 to 16.
# Current worry level is not divisible by 19.
# Item with worry level 16 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 258.
# Worry level increases by 6 to 264.
# Monkey gets bored with item, Worry level is divided by 3 to 88.
# Current worry level is not divisible by 19.
# Item with worry level 88 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3109.
# Worry level increases by 3 to 3112.
# Monkey gets bored with item, Worry level is divided by 3 to 1037.
# Current worry level is divisible by 17.
# Item with worry level 1037 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 57.
# Worry level increases by 3 to 60.
# Monkey gets bored with item, Worry level is divided by 3 to 20.
# Current worry level is not divisible by 17.
# Item with worry level 20 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 329.
# Worry level increases by 3 to 332.
# Monkey gets bored with item, Worry level is divided by 3 to 110.
# Current worry level is not divisible by 17.
# Item with worry level 110 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 614.
# Worry level increases by 3 to 617.
# Monkey gets bored with item, Worry level is divided by 3 to 205.
# Current worry level is not divisible by 17.
# Item with worry level 205 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 1570.
# Worry level increases by 3 to 1573.
# Monkey gets bored with item, Worry level is divided by 3 to 524.
# Current worry level is not divisible by 17.
# Item with worry level 524 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 215.
# Worry level increases by 3 to 218.
# Monkey gets bored with item, Worry level is divided by 3 to 72.
# Current worry level is not divisible by 17.
# Item with worry level 72 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 15.
# Worry level is multiplied by 19 to 285.
# Monkey gets bored with item, Worry level is divided by 3 to 95.
# Current worry level is not divisible by 23.
# Item with worry level 95 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 17.
# Worry level is multiplied by 19 to 323.
# Monkey gets bored with item, Worry level is divided by 3 to 107.
# Current worry level is not divisible by 23.
# Item with worry level 107 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 16.
# Worry level is multiplied by 19 to 304.
# Monkey gets bored with item, Worry level is divided by 3 to 101.
# Current worry level is not divisible by 23.
# Item with worry level 101 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 88.
# Worry level is multiplied by 19 to 1672.
# Monkey gets bored with item, Worry level is divided by 3 to 557.
# Current worry level is not divisible by 23.
# Item with worry level 557 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 1037.
# Worry level is multiplied by 19 to 19703.
# Monkey gets bored with item, Worry level is divided by 3 to 6567.
# Current worry level is not divisible by 23.
# Item with worry level 6567 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 20.
# Worry level increases by 6 to 26.
# Monkey gets bored with item, Worry level is divided by 3 to 8.
# Current worry level is not divisible by 19.
# Item with worry level 8 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 110.
# Worry level increases by 6 to 116.
# Monkey gets bored with item, Worry level is divided by 3 to 38.
# Current worry level is divisible by 19.
# Item with worry level 38 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 205.
# Worry level increases by 6 to 211.
# Monkey gets bored with item, Worry level is divided by 3 to 70.
# Current worry level is not divisible by 19.
# Item with worry level 70 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 524.
# Worry level increases by 6 to 530.
# Monkey gets bored with item, Worry level is divided by 3 to 176.
# Current worry level is not divisible by 19.
# Item with worry level 176 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 72.
# Worry level increases by 6 to 78.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 19.
# Item with worry level 26 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 38.
# Worry level is multiplied by 38 to 1444.
# Monkey gets bored with item, Worry level is divided by 3 to 481.
# Current worry level is divisible by 13.
# Item with worry level 481 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 95.
# Worry level increases by 3 to 98.
# Monkey gets bored with item, Worry level is divided by 3 to 32.
# Current worry level is not divisible by 17.
# Item with worry level 32 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 107.
# Worry level increases by 3 to 110.
# Monkey gets bored with item, Worry level is divided by 3 to 36.
# Current worry level is not divisible by 17.
# Item with worry level 36 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 101.
# Worry level increases by 3 to 104.
# Monkey gets bored with item, Worry level is divided by 3 to 34.
# Current worry level is divisible by 17.
# Item with worry level 34 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 557.
# Worry level increases by 3 to 560.
# Monkey gets bored with item, Worry level is divided by 3 to 186.
# Current worry level is not divisible by 17.
# Item with worry level 186 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 6567.
# Worry level increases by 3 to 6570.
# Monkey gets bored with item, Worry level is divided by 3 to 2190.
# Current worry level is not divisible by 17.
# Item with worry level 2190 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 8.
# Worry level is multiplied by 19 to 152.
# Monkey gets bored with item, Worry level is divided by 3 to 50.
# Current worry level is not divisible by 23.
# Item with worry level 50 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 70.
# Worry level is multiplied by 19 to 1330.
# Monkey gets bored with item, Worry level is divided by 3 to 443.
# Current worry level is not divisible by 23.
# Item with worry level 443 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 176.
# Worry level is multiplied by 19 to 3344.
# Monkey gets bored with item, Worry level is divided by 3 to 1114.
# Current worry level is not divisible by 23.
# Item with worry level 1114 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 26.
# Worry level is multiplied by 19 to 494.
# Monkey gets bored with item, Worry level is divided by 3 to 164.
# Current worry level is not divisible by 23.
# Item with worry level 164 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 34.
# Worry level is multiplied by 19 to 646.
# Monkey gets bored with item, Worry level is divided by 3 to 215.
# Current worry level is not divisible by 23.
# Item with worry level 215 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 481.
# Worry level increases by 6 to 487.
# Monkey gets bored with item, Worry level is divided by 3 to 162.
# Current worry level is not divisible by 19.
# Item with worry level 162 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 32.
# Worry level increases by 6 to 38.
# Monkey gets bored with item, Worry level is divided by 3 to 12.
# Current worry level is not divisible by 19.
# Item with worry level 12 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 36.
# Worry level increases by 6 to 42.
# Monkey gets bored with item, Worry level is divided by 3 to 14.
# Current worry level is not divisible by 19.
# Item with worry level 14 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 186.
# Worry level increases by 6 to 192.
# Monkey gets bored with item, Worry level is divided by 3 to 64.
# Current worry level is not divisible by 19.
# Item with worry level 64 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 2190.
# Worry level increases by 6 to 2196.
# Monkey gets bored with item, Worry level is divided by 3 to 732.
# Current worry level is not divisible by 19.
# Item with worry level 732 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 50.
# Worry level increases by 3 to 53.
# Monkey gets bored with item, Worry level is divided by 3 to 17.
# Current worry level is divisible by 17.
# Item with worry level 17 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 443.
# Worry level increases by 3 to 446.
# Monkey gets bored with item, Worry level is divided by 3 to 148.
# Current worry level is not divisible by 17.
# Item with worry level 148 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 1114.
# Worry level increases by 3 to 1117.
# Monkey gets bored with item, Worry level is divided by 3 to 372.
# Current worry level is not divisible by 17.
# Item with worry level 372 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 164.
# Worry level increases by 3 to 167.
# Monkey gets bored with item, Worry level is divided by 3 to 55.
# Current worry level is not divisible by 17.
# Item with worry level 55 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 215.
# Worry level increases by 3 to 218.
# Monkey gets bored with item, Worry level is divided by 3 to 72.
# Current worry level is not divisible by 17.
# Item with worry level 72 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 162.
# Worry level is multiplied by 19 to 3078.
# Monkey gets bored with item, Worry level is divided by 3 to 1026.
# Current worry level is not divisible by 23.
# Item with worry level 1026 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 12.
# Worry level is multiplied by 19 to 228.
# Monkey gets bored with item, Worry level is divided by 3 to 76.
# Current worry level is not divisible by 23.
# Item with worry level 76 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 14.
# Worry level is multiplied by 19 to 266.
# Monkey gets bored with item, Worry level is divided by 3 to 88.
# Current worry level is not divisible by 23.
# Item with worry level 88 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 64.
# Worry level is multiplied by 19 to 1216.
# Monkey gets bored with item, Worry level is divided by 3 to 405.
# Current worry level is not divisible by 23.
# Item with worry level 405 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 732.
# Worry level is multiplied by 19 to 13908.
# Monkey gets bored with item, Worry level is divided by 3 to 4636.
# Current worry level is not divisible by 23.
# Item with worry level 4636 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 17.
# Worry level is multiplied by 19 to 323.
# Monkey gets bored with item, Worry level is divided by 3 to 107.
# Current worry level is not divisible by 23.
# Item with worry level 107 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 148.
# Worry level increases by 6 to 154.
# Monkey gets bored with item, Worry level is divided by 3 to 51.
# Current worry level is not divisible by 19.
# Item with worry level 51 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 372.
# Worry level increases by 6 to 378.
# Monkey gets bored with item, Worry level is divided by 3 to 126.
# Current worry level is not divisible by 19.
# Item with worry level 126 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 55.
# Worry level increases by 6 to 61.
# Monkey gets bored with item, Worry level is divided by 3 to 20.
# Current worry level is not divisible by 19.
# Item with worry level 20 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 72.
# Worry level increases by 6 to 78.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 19.
# Item with worry level 26 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 1026.
# Worry level increases by 3 to 1029.
# Monkey gets bored with item, Worry level is divided by 3 to 343.
# Current worry level is not divisible by 17.
# Item with worry level 343 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 76.
# Worry level increases by 3 to 79.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 17.
# Item with worry level 26 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 88.
# Worry level increases by 3 to 91.
# Monkey gets bored with item, Worry level is divided by 3 to 30.
# Current worry level is not divisible by 17.
# Item with worry level 30 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 405.
# Worry level increases by 3 to 408.
# Monkey gets bored with item, Worry level is divided by 3 to 136.
# Current worry level is divisible by 17.
# Item with worry level 136 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 4636.
# Worry level increases by 3 to 4639.
# Monkey gets bored with item, Worry level is divided by 3 to 1546.
# Current worry level is not divisible by 17.
# Item with worry level 1546 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 107.
# Worry level increases by 3 to 110.
# Monkey gets bored with item, Worry level is divided by 3 to 36.
# Current worry level is not divisible by 17.
# Item with worry level 36 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 51.
# Worry level is multiplied by 19 to 969.
# Monkey gets bored with item, Worry level is divided by 3 to 323.
# Current worry level is not divisible by 23.
# Item with worry level 323 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 126.
# Worry level is multiplied by 19 to 2394.
# Monkey gets bored with item, Worry level is divided by 3 to 798.
# Current worry level is not divisible by 23.
# Item with worry level 798 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 20.
# Worry level is multiplied by 19 to 380.
# Monkey gets bored with item, Worry level is divided by 3 to 126.
# Current worry level is not divisible by 23.
# Item with worry level 126 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 26.
# Worry level is multiplied by 19 to 494.
# Monkey gets bored with item, Worry level is divided by 3 to 164.
# Current worry level is not divisible by 23.
# Item with worry level 164 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 136.
# Worry level is multiplied by 19 to 2584.
# Monkey gets bored with item, Worry level is divided by 3 to 861.
# Current worry level is not divisible by 23.
# Item with worry level 861 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 343.
# Worry level increases by 6 to 349.
# Monkey gets bored with item, Worry level is divided by 3 to 116.
# Current worry level is not divisible by 19.
# Item with worry level 116 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 26.
# Worry level increases by 6 to 32.
# Monkey gets bored with item, Worry level is divided by 3 to 10.
# Current worry level is not divisible by 19.
# Item with worry level 10 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 30.
# Worry level increases by 6 to 36.
# Monkey gets bored with item, Worry level is divided by 3 to 12.
# Current worry level is not divisible by 19.
# Item with worry level 12 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 1546.
# Worry level increases by 6 to 1552.
# Monkey gets bored with item, Worry level is divided by 3 to 517.
# Current worry level is not divisible by 19.
# Item with worry level 517 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 36.
# Worry level increases by 6 to 42.
# Monkey gets bored with item, Worry level is divided by 3 to 14.
# Current worry level is not divisible by 19.
# Item with worry level 14 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 323.
# Worry level increases by 3 to 326.
# Monkey gets bored with item, Worry level is divided by 3 to 108.
# Current worry level is not divisible by 17.
# Item with worry level 108 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 798.
# Worry level increases by 3 to 801.
# Monkey gets bored with item, Worry level is divided by 3 to 267.
# Current worry level is not divisible by 17.
# Item with worry level 267 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 126.
# Worry level increases by 3 to 129.
# Monkey gets bored with item, Worry level is divided by 3 to 43.
# Current worry level is not divisible by 17.
# Item with worry level 43 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 164.
# Worry level increases by 3 to 167.
# Monkey gets bored with item, Worry level is divided by 3 to 55.
# Current worry level is not divisible by 17.
# Item with worry level 55 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 861.
# Worry level increases by 3 to 864.
# Monkey gets bored with item, Worry level is divided by 3 to 288.
# Current worry level is not divisible by 17.
# Item with worry level 288 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 116.
# Worry level is multiplied by 19 to 2204.
# Monkey gets bored with item, Worry level is divided by 3 to 734.
# Current worry level is not divisible by 23.
# Item with worry level 734 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 10.
# Worry level is multiplied by 19 to 190.
# Monkey gets bored with item, Worry level is divided by 3 to 63.
# Current worry level is not divisible by 23.
# Item with worry level 63 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 12.
# Worry level is multiplied by 19 to 228.
# Monkey gets bored with item, Worry level is divided by 3 to 76.
# Current worry level is not divisible by 23.
# Item with worry level 76 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 517.
# Worry level is multiplied by 19 to 9823.
# Monkey gets bored with item, Worry level is divided by 3 to 3274.
# Current worry level is not divisible by 23.
# Item with worry level 3274 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 14.
# Worry level is multiplied by 19 to 266.
# Monkey gets bored with item, Worry level is divided by 3 to 88.
# Current worry level is not divisible by 23.
# Item with worry level 88 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 108.
# Worry level increases by 6 to 114.
# Monkey gets bored with item, Worry level is divided by 3 to 38.
# Current worry level is divisible by 19.
# Item with worry level 38 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 267.
# Worry level increases by 6 to 273.
# Monkey gets bored with item, Worry level is divided by 3 to 91.
# Current worry level is not divisible by 19.
# Item with worry level 91 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 43.
# Worry level increases by 6 to 49.
# Monkey gets bored with item, Worry level is divided by 3 to 16.
# Current worry level is not divisible by 19.
# Item with worry level 16 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 55.
# Worry level increases by 6 to 61.
# Monkey gets bored with item, Worry level is divided by 3 to 20.
# Current worry level is not divisible by 19.
# Item with worry level 20 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 288.
# Worry level increases by 6 to 294.
# Monkey gets bored with item, Worry level is divided by 3 to 98.
# Current worry level is not divisible by 19.
# Item with worry level 98 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 38.
# Worry level is multiplied by 38 to 1444.
# Monkey gets bored with item, Worry level is divided by 3 to 481.
# Current worry level is divisible by 13.
# Item with worry level 481 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 734.
# Worry level increases by 3 to 737.
# Monkey gets bored with item, Worry level is divided by 3 to 245.
# Current worry level is not divisible by 17.
# Item with worry level 245 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 63.
# Worry level increases by 3 to 66.
# Monkey gets bored with item, Worry level is divided by 3 to 22.
# Current worry level is not divisible by 17.
# Item with worry level 22 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 76.
# Worry level increases by 3 to 79.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 17.
# Item with worry level 26 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 3274.
# Worry level increases by 3 to 3277.
# Monkey gets bored with item, Worry level is divided by 3 to 1092.
# Current worry level is not divisible by 17.
# Item with worry level 1092 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 88.
# Worry level increases by 3 to 91.
# Monkey gets bored with item, Worry level is divided by 3 to 30.
# Current worry level is not divisible by 17.
# Item with worry level 30 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 91.
# Worry level is multiplied by 19 to 1729.
# Monkey gets bored with item, Worry level is divided by 3 to 576.
# Current worry level is not divisible by 23.
# Item with worry level 576 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 16.
# Worry level is multiplied by 19 to 304.
# Monkey gets bored with item, Worry level is divided by 3 to 101.
# Current worry level is not divisible by 23.
# Item with worry level 101 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 20.
# Worry level is multiplied by 19 to 380.
# Monkey gets bored with item, Worry level is divided by 3 to 126.
# Current worry level is not divisible by 23.
# Item with worry level 126 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 98.
# Worry level is multiplied by 19 to 1862.
# Monkey gets bored with item, Worry level is divided by 3 to 620.
# Current worry level is not divisible by 23.
# Item with worry level 620 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 481.
# Worry level increases by 6 to 487.
# Monkey gets bored with item, Worry level is divided by 3 to 162.
# Current worry level is not divisible by 19.
# Item with worry level 162 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 245.
# Worry level increases by 6 to 251.
# Monkey gets bored with item, Worry level is divided by 3 to 83.
# Current worry level is not divisible by 19.
# Item with worry level 83 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 22.
# Worry level increases by 6 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 19.
# Item with worry level 9 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 26.
# Worry level increases by 6 to 32.
# Monkey gets bored with item, Worry level is divided by 3 to 10.
# Current worry level is not divisible by 19.
# Item with worry level 10 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 1092.
# Worry level increases by 6 to 1098.
# Monkey gets bored with item, Worry level is divided by 3 to 366.
# Current worry level is not divisible by 19.
# Item with worry level 366 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 30.
# Worry level increases by 6 to 36.
# Monkey gets bored with item, Worry level is divided by 3 to 12.
# Current worry level is not divisible by 19.
# Item with worry level 12 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 576.
# Worry level increases by 3 to 579.
# Monkey gets bored with item, Worry level is divided by 3 to 193.
# Current worry level is not divisible by 17.
# Item with worry level 193 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 101.
# Worry level increases by 3 to 104.
# Monkey gets bored with item, Worry level is divided by 3 to 34.
# Current worry level is divisible by 17.
# Item with worry level 34 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 126.
# Worry level increases by 3 to 129.
# Monkey gets bored with item, Worry level is divided by 3 to 43.
# Current worry level is not divisible by 17.
# Item with worry level 43 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 620.
# Worry level increases by 3 to 623.
# Monkey gets bored with item, Worry level is divided by 3 to 207.
# Current worry level is not divisible by 17.
# Item with worry level 207 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 162.
# Worry level is multiplied by 19 to 3078.
# Monkey gets bored with item, Worry level is divided by 3 to 1026.
# Current worry level is not divisible by 23.
# Item with worry level 1026 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 83.
# Worry level is multiplied by 19 to 1577.
# Monkey gets bored with item, Worry level is divided by 3 to 525.
# Current worry level is not divisible by 23.
# Item with worry level 525 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 9.
# Worry level is multiplied by 19 to 171.
# Monkey gets bored with item, Worry level is divided by 3 to 57.
# Current worry level is not divisible by 23.
# Item with worry level 57 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 10.
# Worry level is multiplied by 19 to 190.
# Monkey gets bored with item, Worry level is divided by 3 to 63.
# Current worry level is not divisible by 23.
# Item with worry level 63 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 366.
# Worry level is multiplied by 19 to 6954.
# Monkey gets bored with item, Worry level is divided by 3 to 2318.
# Current worry level is not divisible by 23.
# Item with worry level 2318 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 12.
# Worry level is multiplied by 19 to 228.
# Monkey gets bored with item, Worry level is divided by 3 to 76.
# Current worry level is not divisible by 23.
# Item with worry level 76 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 34.
# Worry level is multiplied by 19 to 646.
# Monkey gets bored with item, Worry level is divided by 3 to 215.
# Current worry level is not divisible by 23.
# Item with worry level 215 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 193.
# Worry level increases by 6 to 199.
# Monkey gets bored with item, Worry level is divided by 3 to 66.
# Current worry level is not divisible by 19.
# Item with worry level 66 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 43.
# Worry level increases by 6 to 49.
# Monkey gets bored with item, Worry level is divided by 3 to 16.
# Current worry level is not divisible by 19.
# Item with worry level 16 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 207.
# Worry level increases by 6 to 213.
# Monkey gets bored with item, Worry level is divided by 3 to 71.
# Current worry level is not divisible by 19.
# Item with worry level 71 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 1026.
# Worry level increases by 3 to 1029.
# Monkey gets bored with item, Worry level is divided by 3 to 343.
# Current worry level is not divisible by 17.
# Item with worry level 343 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 525.
# Worry level increases by 3 to 528.
# Monkey gets bored with item, Worry level is divided by 3 to 176.
# Current worry level is not divisible by 17.
# Item with worry level 176 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 57.
# Worry level increases by 3 to 60.
# Monkey gets bored with item, Worry level is divided by 3 to 20.
# Current worry level is not divisible by 17.
# Item with worry level 20 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 63.
# Worry level increases by 3 to 66.
# Monkey gets bored with item, Worry level is divided by 3 to 22.
# Current worry level is not divisible by 17.
# Item with worry level 22 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 2318.
# Worry level increases by 3 to 2321.
# Monkey gets bored with item, Worry level is divided by 3 to 773.
# Current worry level is not divisible by 17.
# Item with worry level 773 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 76.
# Worry level increases by 3 to 79.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 17.
# Item with worry level 26 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 215.
# Worry level increases by 3 to 218.
# Monkey gets bored with item, Worry level is divided by 3 to 72.
# Current worry level is not divisible by 17.
# Item with worry level 72 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 66.
# Worry level is multiplied by 19 to 1254.
# Monkey gets bored with item, Worry level is divided by 3 to 418.
# Current worry level is not divisible by 23.
# Item with worry level 418 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 16.
# Worry level is multiplied by 19 to 304.
# Monkey gets bored with item, Worry level is divided by 3 to 101.
# Current worry level is not divisible by 23.
# Item with worry level 101 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 71.
# Worry level is multiplied by 19 to 1349.
# Monkey gets bored with item, Worry level is divided by 3 to 449.
# Current worry level is not divisible by 23.
# Item with worry level 449 is thrown to monkey 3.
# Monkey inspects an item with a worry level of 343.
# Worry level increases by 6 to 349.
# Monkey gets bored with item, Worry level is divided by 3 to 116.
# Current worry level is not divisible by 19.
# Item with worry level 116 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 176.
# Worry level increases by 6 to 182.
# Monkey gets bored with item, Worry level is divided by 3 to 60.
# Current worry level is not divisible by 19.
# Item with worry level 60 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 20.
# Worry level increases by 6 to 26.
# Monkey gets bored with item, Worry level is divided by 3 to 8.
# Current worry level is not divisible by 19.
# Item with worry level 8 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 22.
# Worry level increases by 6 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 19.
# Item with worry level 9 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 773.
# Worry level increases by 6 to 779.
# Monkey gets bored with item, Worry level is divided by 3 to 259.
# Current worry level is not divisible by 19.
# Item with worry level 259 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 26.
# Worry level increases by 6 to 32.
# Monkey gets bored with item, Worry level is divided by 3 to 10.
# Current worry level is not divisible by 19.
# Item with worry level 10 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 72.
# Worry level increases by 6 to 78.
# Monkey gets bored with item, Worry level is divided by 3 to 26.
# Current worry level is not divisible by 19.
# Item with worry level 26 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 418.
# Worry level increases by 3 to 421.
# Monkey gets bored with item, Worry level is divided by 3 to 140.
# Current worry level is not divisible by 17.
# Item with worry level 140 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 101.
# Worry level increases by 3 to 104.
# ...
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 7 to 21.
# Monkey gets bored with item, Worry level is divided by 3 to 7.
# Current worry level is not divisible by 11.
# Item with worry level 7 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 4.
# Worry level is multiplied by 7 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 11.
# Item with worry level 9 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 4.
# Worry level is multiplied by 7 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 11.
# Item with worry level 9 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 4.
# Worry level is multiplied by 7 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 11.
# Item with worry level 9 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 4.
# Worry level is multiplied by 7 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 11.
# Item with worry level 9 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 4.
# Worry level is multiplied by 7 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 11.
# Item with worry level 9 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 4.
# Worry level is multiplied by 7 to 28.
# Monkey gets bored with item, Worry level is divided by 3 to 9.
# Current worry level is not divisible by 11.
# Item with worry level 9 is thrown to monkey 6.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 13 to 39.
# Monkey gets bored with item, Worry level is divided by 3 to 13.
# Current worry level is not divisible by 5.
# Item with worry level 13 is thrown to monkey 4.
# Monkey inspects an item with a worry level of 3.
# Worry level is multiplied by 13 to 39.
# Monkey gets bored with item, Worry level is divided by 3 to 13.
# Current worry level is not divisible by 5.
# Item with worry level 13 is thrown to monkey 4.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 4.
# Worry level increases by 1 to 5.
# Monkey gets bored with item, Worry level is divided by 3 to 1.
# Current worry level is not divisible by 7.
# Item with worry level 1 is thrown to monkey 7.
# Monkey inspects an item with a worry level of 13.
# Worry level increases by 7 to 20.
# Monkey gets bored with item, Worry level is divided by 3 to 6.
# Current worry level is not divisible by 17.
# Item with worry level 6 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 13.
# Worry level increases by 7 to 20.
# Monkey gets bored with item, Worry level is divided by 3 to 6.
# Current worry level is not divisible by 17.
# Item with worry level 6 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 3.
# Worry level increases by 6 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 13.
# Item with worry level 3 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 6.
# Worry level increases by 6 to 12.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 13.
# Item with worry level 4 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 6.
# Worry level increases by 6 to 12.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 13.
# Item with worry level 4 is thrown to monkey 0.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 7.
# Worry level increases by 4 to 11.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is divisible by 3.
# Item with worry level 3 is thrown to monkey 1.
# Monkey inspects an item with a worry level of 9.
# Worry level increases by 4 to 13.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 3.
# Item with worry level 4 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 9.
# Worry level increases by 4 to 13.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 3.
# Item with worry level 4 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 9.
# Worry level increases by 4 to 13.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 3.
# Item with worry level 4 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 9.
# Worry level increases by 4 to 13.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 3.
# Item with worry level 4 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 9.
# Worry level increases by 4 to 13.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 3.
# Item with worry level 4 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 9.
# Worry level increases by 4 to 13.
# Monkey gets bored with item, Worry level is divided by 3 to 4.
# Current worry level is not divisible by 3.
# Item with worry level 4 is thrown to monkey 2.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# Monkey inspects an item with a worry level of 1.
# Worry level increases by 8 to 9.
# Monkey gets bored with item, Worry level is divided by 3 to 3.
# Current worry level is not divisible by 19.
# Item with worry level 3 is thrown to monkey 5.
# [282, 280, 276, 152, 150, 137, 133, 5]
# 78960
